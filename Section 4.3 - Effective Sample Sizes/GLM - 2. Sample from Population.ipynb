# %% [markdown]
# How the simulation is done:
# - First, a base simulation is done per sample size.
# - Then, as needed, more simulations are done by upticking the iteration values.

# %% [markdown]
# # Imports:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression

from scipy.stats import chi2
from collections import Counter

from itertools import permutations
from tqdm import tqdm, trange

# %%
import pickle
import statsmodels.api as sm
from collections import defaultdict
from scipy.special import expit, logit

# %% [markdown]
# # Helper Functions:

# %%
import sys

sys.path.append('../')

from ddc_utils import *
from data_generating_utils import *

# %%
def is_binomial_data_seperable(
    df: pd.DataFrame, binary_col: str, cont_col: str
) -> bool:
    """
    Given a dataframe, column for binary rv, and column for continuous rv, returns True if the
        binary rv is seperable.
    """
    separability_check_df = (
        df[[binary_col, cont_col]].groupby(binary_col)[cont_col].agg(["min", "max"])
    )

    # checks if there is y = 0, y = 1, as well as whether min(y = 0) > max(y = 1), and vice versa
    return (
        (len(separability_check_df) < 2)
        or (separability_check_df.iloc[0, 0] > separability_check_df.iloc[1, 1])
        or (separability_check_df.iloc[1, 0] > separability_check_df.iloc[0, 1])
    )

def to_pickle_obj(file_path, raw_data):
    with open(file_path, "wb") as handle:
        pickle.dump(raw_data, handle)

def read_pickle_obj(file_path):
    with open(file_path, 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# # Hyperparams:

# %%
pop_index = 1
iter_val = 4

# %%
rand_generator = np.random.default_rng(seed=333 * pop_index + iter_val)

# %%
population_size = 100_000
number_of_coefficients = 1

num_iters_per_population_for_small_samples = 50_000
num_iters_per_population_for_large_samples = 5_000
small_large_sample_co = 100

# biased sampling scheme params:
sample_probability_centering = 0.77
sample_probability_bias_factor = 1

# %%
# iter 0:
# ALL_SAMPLE_SIZES = (
#     [i for i in range(35, 45)]
#     + [50, 70, 100, 150, 250, 400, 600, 1000, 1400]
#     + [2000, 3000, 5000, 7500, 10_000, 15_000, 20_000]
# )


# iter 2-4:
ALL_SAMPLE_SIZES = (
    [30, 31, 33, 35, 37, 39, 40]
    + [50, 70, 100, 150, 200, 250, 300, 350, 400, 500, 600, 700, 800, 900, 1000, 1400]
)

# %% [markdown]
# # Load Finite Population Data:

# %%
pickle_filename = f'base_population_data_Logit_1.pickle'
pop_data = pd.read_pickle(pickle_filename)

# %% [markdown]
# # Run:

# %%
feature_cols = [f'x_{i}' for i in range(number_of_coefficients)]

# %%
sample_specific_non_separable_count = {}

# %% [markdown]
# #### get population-level statistics:

# %%
pop_x = pop_data[feature_cols]
pop_y = pop_data['y']

pop_model = sm.Logit(endog = pop_y, exog = pop_x).fit(disp=0)
pop_beta = np.array(pop_model.params)
pop_gs = pop_x * (np.array(pop_y).reshape((population_size, 1)) - \
              np.array(pop_model.predict()).reshape((population_size, 1)))

# %% [markdown]
# #### actually run:

# %%
for temp_sample_size in tqdm(ALL_SAMPLE_SIZES):
    # where the data will be saved:
    all_jns_biased, all_ddc_biased, all_sample_beta_biased = [], [], []
    all_jns_full, all_ddc_full, all_sample_beta_full = [], [], []

    all_realized_sample_sizes = []

    # set up how much to sample for this population:
    non_separable_count = 0
    if temp_sample_size < small_large_sample_co:
        num_iters_per_population = num_iters_per_population_for_small_samples
    else:
        num_iters_per_population = num_iters_per_population_for_large_samples

    for _ in trange(num_iters_per_population, mininterval=10):
        """
            First, sample a valid dataset (which is not seperable):
        """
        # use sampling scheme to sample data:
        obtained_valid_sample = False

        while not obtained_valid_sample:
            # intended sample:
            pop_data["r0"] = 0
            pop_data.loc[
                np.random.choice(pop_data.index, size=temp_sample_size, replace=False),
                "r0",
            ] = 1

            full_sampled_data = pop_data[pop_data["r0"] == 1]
            
            # biased sample:
            pop_data["r"] = 0
            
            marginal_probabilities = expit(
                logit(sample_probability_centering)
                + sample_probability_bias_factor
                * (2 * full_sampled_data["y"] - 1)
                * full_sampled_data["x_0"]
            )
            other_sample_indices = marginal_probabilities.index[
                rand_generator.binomial(n=1, p=marginal_probabilities) == 1
            ]
            pop_data.loc[other_sample_indices, "r"] = 1

            # sample_data here means the biased sample data.
            sample_data = pop_data[pop_data["r"] == 1]

            # if the sample size is too small, check for seperability:
            realised_sample_size = len(other_sample_indices)
            if realised_sample_size < 1_000:
                if is_binomial_data_seperable(sample_data, 'y', 'x_0'):
                    non_separable_count = non_separable_count + 1
                    continue
            
            obtained_valid_sample = True
        
        """
            Then, compute the logistic betas, ddc, Jns:
        """
        # compute biased x, y, model, beta
        sample_x, sample_y = sample_data[feature_cols], sample_data["y"]
        sample_beta = np.array(
            sm.Logit(endog=sample_y, exog=sample_x).fit(disp=0, maxiter=5_00).params
        )
        sample_r = pop_data["r"]

        # compute full x, y, model, beta
        sample_x_full, sample_y_full = (
            full_sampled_data[feature_cols],
            full_sampled_data["y"],
        )
        sample_beta_full = np.array(
            sm.Logit(endog=sample_y_full, exog=sample_x_full)
            .fit(disp=0, maxiter=5_00)
            .params
        )
        sample_r_full = pop_data["r0"]

        # compute biased versions of things:
        all_sample_beta_biased.append(pd.Series(sample_beta))
        all_ddc_biased.append(pop_gs.corrwith(sample_r)[["x_0"]])
        all_jns_biased.append(
            compute_average_jn(
                pop_beta, sample_beta, sample_x, sample_y, model_type="Logit"
            )
        )

        all_realized_sample_sizes.append(realised_sample_size)

        # compute full versions of things:
        all_sample_beta_full.append(pd.Series(sample_beta_full))
        all_ddc_full.append(pop_gs.corrwith(sample_r_full)[["x_0"]])
        all_jns_full.append(
            compute_average_jn(
                pop_beta,
                sample_beta_full,
                sample_x_full,
                sample_y_full,
                model_type="Logit",
            )
        )

    sample_specific_non_separable_count[temp_sample_size] = non_separable_count

    """
        Save the data!
    """
    # concatenate the biased versions:
    temp_samp_beta_biased = pd.concat(all_sample_beta_biased, axis=1).T
    temp_ddc_biased = pd.concat(all_ddc_biased, axis=1).T
    temp_jn_biased = pd.concat(all_jns_biased, axis=1).T.reset_index(drop=True)
    realised_sizes = pd.Series(all_realized_sample_sizes)

    # concat the SRS versions:
    temp_samp_beta_full = pd.concat(all_sample_beta_full, axis=1).T
    temp_ddc_full = pd.concat(all_ddc_full, axis=1).T
    temp_jn_full = pd.concat(all_jns_full, axis=1).T.reset_index(drop=True)

    temp_ss_data = pd.concat(
        [
            temp_samp_beta_biased,
            temp_ddc_biased,
            temp_jn_biased,
            realised_sizes,
            temp_samp_beta_full,
            temp_ddc_full,
            temp_jn_full,
        ],
        axis=1,
    )
    temp_ss_data.columns = [
        "samp_biased",
        "ddc_biased",
        "jn_biased",
        "realized_size_biased",
        "samp_intended",
        "ddc_intended",
        "jn_intended",
    ]

    temp_ss_data["sample_size"] = temp_sample_size
    temp_ss_data["pop_beta"] = pop_beta[0]

    temp_ss_data["mse_biased"] = (
        temp_ss_data["pop_beta"] - temp_ss_data["samp_biased"]
    ) ** 2

    temp_ss_data["mse_intended"] = (
        temp_ss_data["pop_beta"] - temp_ss_data["samp_intended"]
    ) ** 2

    to_pickle_obj(f"sim_results/sim_{temp_sample_size}_iter_{iter_val}.pickle", temp_ss_data)
# Out:
#   0%|                                                                                           | 0/23 [00:00<?, ?it/s]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▌                                                                            | 972/50000 [00:10<08:24, 97.17it/s]
# %|███                                                                         | 1994/50000 [00:20<07:59, 100.12it/s]
# %|███                                                                         | 1994/50000 [00:30<07:59, 100.12it/s]
# %|████▌                                                                       | 3005/50000 [00:30<07:47, 100.48it/s]
# %|██████▏                                                                     | 4067/50000 [00:40<07:27, 102.73it/s]
# %|██████▏                                                                     | 4067/50000 [00:50<07:27, 102.73it/s]
# %|███████▋                                                                    | 5082/50000 [00:50<07:19, 102.21it/s]
# %|███████▋                                                                    | 5082/50000 [01:00<07:19, 102.21it/s]
# %|█████████▏                                                                   | 5977/50000 [01:00<07:30, 97.81it/s]
# %|█████████▏                                                                   | 5977/50000 [01:10<07:30, 97.81it/s]
# %|██████████▎                                                                  | 6658/50000 [01:10<08:12, 88.04it/s]
# %|███████████▋                                                                 | 7575/50000 [01:20<07:55, 89.19it/s]
# %|█████████████▎                                                               | 8609/50000 [01:30<07:22, 93.61it/s]
# %|██████████████▊                                                              | 9648/50000 [01:40<06:57, 96.77it/s]
# %|████████████████▎                                                           | 10698/50000 [01:50<06:35, 99.27it/s]
# %|████████████████▎                                                           | 10698/50000 [02:00<06:35, 99.27it/s]
# %|█████████████████▌                                                         | 11737/50000 [02:00<06:20, 100.57it/s]
# %|█████████████████▌                                                         | 11737/50000 [02:10<06:20, 100.57it/s]
# %|███████████████████▏                                                       | 12788/50000 [02:10<06:05, 101.93it/s]
# %|███████████████████▏                                                       | 12788/50000 [02:20<06:05, 101.93it/s]
# %|████████████████████▋                                                      | 13823/50000 [02:20<05:53, 102.35it/s]
# %|██████████████████████▎                                                    | 14888/50000 [02:30<05:38, 103.58it/s]
# %|██████████████████████▎                                                    | 14888/50000 [02:40<05:38, 103.58it/s]
# %|███████████████████████▉                                                   | 15942/50000 [02:40<05:27, 104.10it/s]
# %|███████████████████████▉                                                   | 15942/50000 [02:50<05:27, 104.10it/s]
# %|█████████████████████████▍                                                 | 16959/50000 [02:50<05:19, 103.35it/s]
# %|█████████████████████████▍                                                 | 16959/50000 [03:00<05:19, 103.35it/s]
# %|██████████████████████████▉                                                | 17986/50000 [03:00<05:10, 103.13it/s]
# %|████████████████████████████▌                                              | 19037/50000 [03:10<04:58, 103.71it/s]
# %|██████████████████████████████▏                                            | 20093/50000 [03:20<04:46, 104.26it/s]
# %|██████████████████████████████▏                                            | 20093/50000 [03:30<04:46, 104.26it/s]
# %|███████████████████████████████▋                                           | 21100/50000 [03:30<04:40, 103.10it/s]
# %|█████████████████████████████████▏                                         | 22161/50000 [03:40<04:27, 103.98it/s]
# %|█████████████████████████████████▏                                         | 22161/50000 [03:50<04:27, 103.98it/s]
# %|██████████████████████████████████▊                                        | 23216/50000 [03:50<04:16, 104.38it/s]
# %|██████████████████████████████████▊                                        | 23216/50000 [04:00<04:16, 104.38it/s]
# %|████████████████████████████████████▍                                      | 24254/50000 [04:00<04:07, 104.17it/s]
# %|████████████████████████████████████▍                                      | 24254/50000 [04:10<04:07, 104.17it/s]
# %|█████████████████████████████████████▉                                     | 25274/50000 [04:10<03:58, 103.47it/s]
# %|█████████████████████████████████████▉                                     | 25274/50000 [04:20<03:58, 103.47it/s]
# %|███████████████████████████████████████▍                                   | 26255/50000 [04:20<03:53, 101.83it/s]
# %|████████████████████████████████████████▉                                  | 27304/50000 [04:30<03:40, 102.73it/s]
# %|████████████████████████████████████████▉                                  | 27304/50000 [04:40<03:40, 102.73it/s]
# %|██████████████████████████████████████████▌                                | 28363/50000 [04:40<03:28, 103.65it/s]
# %|████████████████████████████████████████████▏                              | 29421/50000 [04:50<03:18, 103.91it/s]
# %|█████████████████████████████████████████████▋                             | 30467/50000 [05:00<03:08, 103.73it/s]
# %|███████████████████████████████████████████████▎                           | 31508/50000 [05:10<02:58, 103.82it/s]
# %|████████████████████████████████████████████████▊                          | 32549/50000 [05:21<02:50, 102.42it/s]
# %|██████████████████████████████████████████████████▎                        | 33543/50000 [05:31<02:43, 100.68it/s]
# %|███████████████████████████████████████████████████▊                       | 34561/50000 [05:41<02:32, 101.01it/s]
# %|█████████████████████████████████████████████████████▎                     | 35579/50000 [05:51<02:22, 100.88it/s]
# %|██████████████████████████████████████████████████████▉                    | 36603/50000 [06:01<02:12, 101.32it/s]
# %|████████████████████████████████████████████████████████▍                  | 37630/50000 [06:11<02:01, 101.71it/s]
# %|██████████████████████████████████████████████████████████                 | 38681/50000 [06:21<01:50, 102.71it/s]
# %|███████████████████████████████████████████████████████████▌               | 39732/50000 [06:31<01:39, 102.76it/s]
# %|█████████████████████████████████████████████████████████████▏             | 40761/50000 [06:41<01:30, 102.52it/s]
# %|██████████████████████████████████████████████████████████████▋            | 41781/50000 [06:52<01:21, 100.75it/s]
# %|████████████████████████████████████████████████████████████████▏          | 42799/50000 [07:02<01:11, 101.03it/s]
# %|█████████████████████████████████████████████████████████████████▋         | 43817/50000 [07:12<01:01, 100.51it/s]
# %|███████████████████████████████████████████████████████████████████▎       | 44849/50000 [07:22<00:50, 101.29it/s]
# %|████████████████████████████████████████████████████████████████████▊      | 45881/50000 [07:32<00:40, 101.38it/s]
# %|██████████████████████████████████████████████████████████████████████▎    | 46902/50000 [07:42<00:30, 101.57it/s]
# %|███████████████████████████████████████████████████████████████████████▉   | 47923/50000 [07:52<00:20, 101.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [08:12<00:00, 101.47it/s]
#   4%|███▍                                                                            | 1/23 [08:19<3:03:06, 499.39s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▌                                                                          | 1065/50000 [00:10<07:39, 106.41it/s]
# %|███▏                                                                        | 2130/50000 [00:20<07:32, 105.75it/s]
# %|████▊                                                                       | 3184/50000 [00:30<07:23, 105.47it/s]
# %|██████▍                                                                     | 4244/50000 [00:40<07:13, 105.67it/s]
# %|████████                                                                    | 5304/50000 [00:50<07:02, 105.68it/s]
# %|█████████▋                                                                  | 6361/50000 [01:00<06:53, 105.56it/s]
# %|███████████▎                                                                | 7415/50000 [01:10<06:45, 104.94it/s]
# %|████████████▉                                                               | 8479/50000 [01:20<06:34, 105.37it/s]
# %|████████████▉                                                               | 8479/50000 [01:30<06:34, 105.37it/s]
# %|██████████████▍                                                             | 9535/50000 [01:30<06:26, 104.77it/s]
# %|██████████████▍                                                             | 9535/50000 [01:40<06:26, 104.77it/s]
# %|███████████████▉                                                           | 10590/50000 [01:40<06:15, 104.98it/s]
# %|███████████████▉                                                           | 10590/50000 [01:50<06:15, 104.98it/s]
# %|█████████████████▍                                                         | 11614/50000 [01:50<06:08, 104.14it/s]
# %|███████████████████                                                        | 12670/50000 [02:00<05:57, 104.56it/s]
# %|███████████████████                                                        | 12670/50000 [02:10<05:57, 104.56it/s]
# %|████████████████████▌                                                      | 13719/50000 [02:10<05:46, 104.64it/s]
# %|████████████████████▌                                                      | 13719/50000 [02:20<05:46, 104.64it/s]
# %|██████████████████████▏                                                    | 14780/50000 [02:20<05:35, 105.07it/s]
# %|██████████████████████▏                                                    | 14780/50000 [02:30<05:35, 105.07it/s]
# %|███████████████████████▋                                                   | 15813/50000 [02:30<05:27, 104.46it/s]
# %|█████████████████████████▎                                                 | 16872/50000 [02:40<05:15, 104.88it/s]
# %|█████████████████████████▎                                                 | 16872/50000 [02:50<05:15, 104.88it/s]
# %|██████████████████████████▉                                                | 17926/50000 [02:50<05:05, 104.98it/s]
# %|████████████████████████████▍                                              | 18979/50000 [03:01<04:58, 104.00it/s]
# %|██████████████████████████████                                             | 20025/50000 [03:11<04:47, 104.15it/s]
# %|███████████████████████████████▌                                           | 21073/50000 [03:21<04:37, 104.33it/s]
# %|█████████████████████████████████▏                                         | 22121/50000 [03:31<04:27, 104.37it/s]
# %|██████████████████████████████████▋                                        | 23166/50000 [03:41<04:18, 103.83it/s]
# %|████████████████████████████████████▎                                      | 24192/50000 [03:52<04:15, 100.93it/s]
# %|██████████████████████████████████████▎                                     | 25168/50000 [04:02<04:08, 99.95it/s]
# %|███████████████████████████████████████▋                                    | 26144/50000 [04:12<04:00, 99.23it/s]
# %|████████████████████████████████████████▊                                  | 27174/50000 [04:22<03:47, 100.34it/s]
# %|██████████████████████████████████████████▎                                | 28208/50000 [04:32<03:35, 101.25it/s]
# %|███████████████████████████████████████████▉                               | 29262/50000 [04:42<03:22, 102.47it/s]
# %|█████████████████████████████████████████████▍                             | 30316/50000 [04:52<03:12, 102.36it/s]
# %|███████████████████████████████████████████████                            | 31405/50000 [05:02<02:58, 104.29it/s]
# %|████████████████████████████████████████████████▋                          | 32494/50000 [05:12<02:46, 105.39it/s]
# %|██████████████████████████████████████████████████▎                        | 33574/50000 [05:22<02:36, 104.79it/s]
# %|███████████████████████████████████████████████████▉                       | 34609/50000 [05:33<02:28, 103.98it/s]
# %|█████████████████████████████████████████████████████▍                     | 35638/50000 [05:43<02:18, 103.65it/s]
# %|███████████████████████████████████████████████████████                    | 36690/50000 [05:53<02:07, 104.10it/s]
# %|████████████████████████████████████████████████████████▌                  | 37742/50000 [06:03<01:59, 102.94it/s]
# %|██████████████████████████████████████████████████████████▏                | 38827/50000 [06:13<01:46, 104.56it/s]
# %|███████████████████████████████████████████████████████████▊               | 39911/50000 [06:23<01:35, 105.38it/s]
# %|█████████████████████████████████████████████████████████████▍             | 40986/50000 [06:33<01:25, 106.01it/s]
# %|███████████████████████████████████████████████████████████████            | 42061/50000 [06:43<01:14, 106.45it/s]
# %|████████████████████████████████████████████████████████████████▋          | 43136/50000 [06:53<01:04, 106.75it/s]
# %|██████████████████████████████████████████████████████████████████▎        | 44211/50000 [07:03<00:54, 106.95it/s]
# %|███████████████████████████████████████████████████████████████████▉       | 45286/50000 [07:13<00:44, 107.07it/s]
# %|█████████████████████████████████████████████████████████████████████▌     | 46365/50000 [07:23<00:33, 107.31it/s]
# %|███████████████████████████████████████████████████████████████████████▏   | 47444/50000 [07:34<00:24, 104.92it/s]
# %|████████████████████████████████████████████████████████████████████████▊  | 48523/50000 [07:44<00:13, 105.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [07:58<00:00, 104.51it/s]
#   9%|██████▉                                                                         | 2/23 [16:24<2:51:46, 490.79s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▋                                                                          | 1072/50000 [00:10<07:36, 107.20it/s]
# %|███▎                                                                        | 2144/50000 [00:20<07:26, 107.10it/s]
# %|████▉                                                                       | 3215/50000 [00:30<07:17, 106.92it/s]
# %|██████▌                                                                     | 4283/50000 [00:40<07:08, 106.61it/s]
# %|████████▏                                                                   | 5362/50000 [00:50<06:57, 107.04it/s]
# %|█████████▊                                                                  | 6441/50000 [01:00<06:49, 106.39it/s]
# %|███████████▍                                                                | 7519/50000 [01:10<06:37, 106.84it/s]
# %|█████████████                                                               | 8597/50000 [01:20<06:29, 106.17it/s]
# %|██████████████▋                                                             | 9670/50000 [01:30<06:18, 106.52it/s]
# %|████████████████                                                           | 10743/50000 [01:41<06:13, 105.18it/s]
# %|█████████████████▋                                                         | 11794/50000 [01:51<06:03, 105.15it/s]
# %|███████████████████▎                                                       | 12851/50000 [02:01<05:54, 104.87it/s]
# %|████████████████████▉                                                      | 13933/50000 [02:11<05:40, 105.86it/s]
# %|██████████████████████▌                                                    | 15018/50000 [02:21<05:28, 106.64it/s]
# %|████████████████████████▏                                                  | 16103/50000 [02:31<05:17, 106.90it/s]
# %|█████████████████████████▊                                                 | 17179/50000 [02:41<05:08, 106.28it/s]
# %|███████████████████████████▍                                               | 18254/50000 [02:51<04:57, 106.62it/s]
# %|████████████████████████████▉                                              | 19331/50000 [03:01<04:46, 106.93it/s]
# %|██████████████████████████████▌                                            | 20408/50000 [03:11<04:36, 106.95it/s]
# %|████████████████████████████████▏                                          | 21478/50000 [03:22<04:29, 105.93it/s]
# %|█████████████████████████████████▊                                         | 22547/50000 [03:32<04:18, 106.19it/s]
# %|███████████████████████████████████▍                                       | 23624/50000 [03:42<04:07, 106.63it/s]
# %|█████████████████████████████████████                                      | 24701/50000 [03:52<03:56, 106.90it/s]
# %|██████████████████████████████████████▋                                    | 25777/50000 [04:02<03:46, 106.95it/s]
# %|████████████████████████████████████████▎                                  | 26848/50000 [04:12<03:39, 105.65it/s]
# %|█████████████████████████████████████████▉                                 | 27925/50000 [04:22<03:27, 106.25it/s]
# %|███████████████████████████████████████████▌                               | 29003/50000 [04:32<03:16, 106.71it/s]
# %|█████████████████████████████████████████████                              | 30081/50000 [04:42<03:06, 106.86it/s]
# %|██████████████████████████████████████████████▋                            | 31154/50000 [04:52<02:56, 106.87it/s]
# %|████████████████████████████████████████████████▎                          | 32229/50000 [05:02<02:46, 107.03it/s]
# %|█████████████████████████████████████████████████▉                         | 33304/50000 [05:13<02:38, 105.31it/s]
# %|███████████████████████████████████████████████████▌                       | 34363/50000 [05:23<02:28, 105.49it/s]
# %|█████████████████████████████████████████████████████▏                     | 35422/50000 [05:33<02:18, 105.24it/s]
# %|██████████████████████████████████████████████████████▋                    | 36469/50000 [05:43<02:08, 104.96it/s]
# %|████████████████████████████████████████████████████████▎                  | 37512/50000 [05:53<02:00, 103.77it/s]
# %|█████████████████████████████████████████████████████████▊                 | 38543/50000 [06:03<01:50, 103.57it/s]
# %|███████████████████████████████████████████████████████████▎               | 39574/50000 [06:13<01:40, 103.29it/s]
# %|████████████████████████████████████████████████████████████▉              | 40617/50000 [06:23<01:30, 103.58it/s]
# %|██████████████████████████████████████████████████████████████▍            | 41660/50000 [06:34<01:22, 101.62it/s]
# %|████████████████████████████████████████████████████████████████           | 42690/50000 [06:44<01:11, 102.02it/s]
# %|█████████████████████████████████████████████████████████████████▌         | 43720/50000 [06:54<01:01, 102.15it/s]
# %|███████████████████████████████████████████████████████████████████        | 44747/50000 [07:04<00:51, 102.30it/s]
# %|████████████████████████████████████████████████████████████████████▋      | 45777/50000 [07:14<00:41, 102.49it/s]
# %|██████████████████████████████████████████████████████████████████████▎    | 46845/50000 [07:24<00:30, 103.77it/s]
# %|███████████████████████████████████████████████████████████████████████▉   | 47923/50000 [07:34<00:19, 104.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [07:53<00:00, 105.49it/s]
#  13%|██████████▍                                                                     | 3/23 [24:25<2:42:07, 486.38s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▌                                                                          | 1067/50000 [00:10<07:38, 106.64it/s]
# %|███▎                                                                        | 2142/50000 [00:20<07:26, 107.11it/s]
# %|████▉                                                                       | 3219/50000 [00:30<07:15, 107.34it/s]
# %|██████▌                                                                     | 4297/50000 [00:40<07:05, 107.48it/s]
# %|████████▏                                                                   | 5376/50000 [00:50<06:54, 107.60it/s]
# %|█████████▊                                                                  | 6455/50000 [01:00<06:48, 106.59it/s]
# %|███████████▍                                                                | 7526/50000 [01:10<06:37, 106.75it/s]
# %|█████████████                                                               | 8597/50000 [01:20<06:30, 105.89it/s]
# %|██████████████▋                                                             | 9655/50000 [01:30<06:21, 105.84it/s]
# %|████████████████                                                           | 10713/50000 [01:40<06:15, 104.70it/s]
# %|█████████████████▋                                                         | 11765/50000 [01:50<06:04, 104.85it/s]
# %|███████████████████▏                                                       | 12817/50000 [02:01<05:55, 104.68it/s]
# %|████████████████████▊                                                      | 13860/50000 [02:11<05:48, 103.80it/s]
# %|██████████████████████▎                                                    | 14909/50000 [02:21<05:37, 104.12it/s]
# %|███████████████████████▉                                                   | 15958/50000 [02:31<05:26, 104.14it/s]
# %|█████████████████████████▌                                                 | 17022/50000 [02:41<05:14, 104.81it/s]
# %|███████████████████████████▏                                               | 18086/50000 [02:51<05:05, 104.56it/s]
# %|████████████████████████████▋                                              | 19160/50000 [03:01<04:52, 105.40it/s]
# %|██████████████████████████████▎                                            | 20234/50000 [03:11<04:42, 105.31it/s]
# %|███████████████████████████████▉                                           | 21304/50000 [03:21<04:31, 105.79it/s]
# %|█████████████████████████████████▌                                         | 22374/50000 [03:32<04:24, 104.52it/s]
# %|███████████████████████████████████▏                                       | 23439/50000 [03:42<04:12, 105.08it/s]
# %|████████████████████████████████████▊                                      | 24506/50000 [03:52<04:01, 105.54it/s]
# %|██████████████████████████████████████▎                                    | 25574/50000 [04:02<03:50, 105.90it/s]
# %|███████████████████████████████████████▉                                   | 26644/50000 [04:12<03:39, 106.19it/s]
# %|█████████████████████████████████████████▌                                 | 27713/50000 [04:22<03:32, 104.83it/s]
# %|███████████████████████████████████████████▏                               | 28779/50000 [04:32<03:21, 105.34it/s]
# %|████████████████████████████████████████████▊                              | 29846/50000 [04:42<03:10, 105.72it/s]
# %|██████████████████████████████████████████████▎                            | 30913/50000 [04:52<03:00, 105.98it/s]
# %|███████████████████████████████████████████████▉                           | 31983/50000 [05:02<02:49, 106.26it/s]
# %|█████████████████████████████████████████████████▌                         | 33053/50000 [05:12<02:39, 106.35it/s]
# %|███████████████████████████████████████████████████▏                       | 34119/50000 [05:23<02:29, 106.14it/s]
# %|████████████████████████████████████████████████████▊                      | 35176/50000 [05:33<02:22, 103.84it/s]
# %|██████████████████████████████████████████████████████▎                    | 36226/50000 [05:43<02:12, 104.17it/s]
# %|███████████████████████████████████████████████████████▉                   | 37290/50000 [05:53<02:01, 104.80it/s]
# %|█████████████████████████████████████████████████████████▌                 | 38359/50000 [06:03<01:50, 105.40it/s]
# %|███████████████████████████████████████████████████████████▏               | 39439/50000 [06:13<01:39, 106.15it/s]
# %|████████████████████████████████████████████████████████████▊              | 40519/50000 [06:23<01:29, 106.34it/s]
# %|██████████████████████████████████████████████████████████████▍            | 41592/50000 [06:33<01:18, 106.60it/s]
# %|███████████████████████████████████████████████████████████████▉           | 42665/50000 [06:44<01:10, 104.71it/s]
# %|█████████████████████████████████████████████████████████████████▌         | 43743/50000 [06:54<00:59, 105.60it/s]
# %|███████████████████████████████████████████████████████████████████▏       | 44821/50000 [07:04<00:49, 105.41it/s]
# %|████████████████████████████████████████████████████████████████████▊      | 45898/50000 [07:14<00:38, 106.06it/s]
# %|██████████████████████████████████████████████████████████████████████▍    | 46974/50000 [07:25<00:28, 105.87it/s]
# %|████████████████████████████████████████████████████████████████████████   | 48034/50000 [07:35<00:18, 105.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [07:53<00:00, 105.61it/s]
#  17%|█████████████▉                                                                  | 4/23 [32:25<2:33:18, 484.14s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▌                                                                          | 1062/50000 [00:10<07:40, 106.19it/s]
# %|███▏                                                                        | 2134/50000 [00:20<07:28, 106.74it/s]
# %|████▊                                                                       | 3206/50000 [00:30<07:18, 106.78it/s]
# %|██████▍                                                                     | 4275/50000 [00:40<07:09, 106.42it/s]
# %|████████▏                                                                   | 5349/50000 [00:50<06:58, 106.75it/s]
# %|█████████▊                                                                  | 6423/50000 [01:00<06:47, 106.88it/s]
# %|███████████▍                                                                | 7497/50000 [01:10<06:37, 107.05it/s]
# %|█████████████                                                               | 8572/50000 [01:20<06:26, 107.17it/s]
# %|██████████████▋                                                             | 9647/50000 [01:30<06:20, 106.09it/s]
# %|████████████████                                                           | 10696/50000 [01:40<06:11, 105.71it/s]
# %|█████████████████▌                                                         | 11745/50000 [01:50<06:02, 105.40it/s]
# %|███████████████████▏                                                       | 12793/50000 [02:00<05:55, 104.52it/s]
# %|████████████████████▊                                                      | 13841/50000 [02:10<05:45, 104.61it/s]
# %|██████████████████████▎                                                    | 14897/50000 [02:20<05:34, 104.90it/s]
# %|███████████████████████▉                                                   | 15953/50000 [02:31<05:27, 104.00it/s]
# %|█████████████████████████▌                                                 | 17003/50000 [02:41<05:16, 104.28it/s]
# %|███████████████████████████                                                | 18053/50000 [02:51<05:05, 104.48it/s]
# %|████████████████████████████▋                                              | 19103/50000 [03:01<04:55, 104.60it/s]
# %|██████████████████████████████▏                                            | 20152/50000 [03:11<04:48, 103.60it/s]
# %|███████████████████████████████▊                                           | 21194/50000 [03:21<04:37, 103.78it/s]
# %|█████████████████████████████████▎                                         | 22236/50000 [03:31<04:27, 103.71it/s]
# %|██████████████████████████████████▉                                        | 23281/50000 [03:41<04:17, 103.94it/s]
# %|████████████████████████████████████▍                                      | 24330/50000 [03:51<04:06, 104.22it/s]
# %|██████████████████████████████████████                                     | 25379/50000 [04:01<03:57, 103.84it/s]
# %|███████████████████████████████████████▋                                   | 26458/50000 [04:11<03:44, 105.05it/s]
# %|█████████████████████████████████████████▎                                 | 27537/50000 [04:21<03:32, 105.74it/s]
# %|██████████████████████████████████████████▉                                | 28612/50000 [04:31<03:21, 106.25it/s]
# %|████████████████████████████████████████████▌                              | 29688/50000 [04:41<03:10, 106.64it/s]
# %|██████████████████████████████████████████████▏                            | 30764/50000 [04:51<02:59, 106.91it/s]
# %|███████████████████████████████████████████████▊                           | 31840/50000 [05:02<02:52, 105.46it/s]
# %|█████████████████████████████████████████████████▎                         | 32916/50000 [05:12<02:41, 106.09it/s]
# %|██████████████████████████████████████████████████▉                        | 33992/50000 [05:22<02:30, 106.23it/s]
# %|████████████████████████████████████████████████████▌                      | 35058/50000 [05:32<02:20, 106.16it/s]
# %|██████████████████████████████████████████████████████▏                    | 36136/50000 [05:42<02:10, 106.64it/s]
# %|███████████████████████████████████████████████████████▊                   | 37214/50000 [05:52<02:00, 105.69it/s]
# %|█████████████████████████████████████████████████████████▍                 | 38250/50000 [06:02<01:51, 104.91it/s]
# %|██████████████████████████████████████████████████████████▉                | 39281/50000 [06:13<01:44, 102.64it/s]
# %|████████████████████████████████████████████████████████████▍              | 40279/50000 [06:23<01:35, 101.80it/s]
# %|██████████████████████████████████████████████████████████████▋             | 41277/50000 [06:35<01:30, 96.63it/s]
# %|████████████████████████████████████████████████████████████████▎           | 42324/50000 [06:45<01:17, 98.94it/s]
# %|█████████████████████████████████████████████████████████████████          | 43371/50000 [06:55<01:06, 100.08it/s]
# %|██████████████████████████████████████████████████████████████████▌        | 44406/50000 [07:05<00:55, 101.06it/s]
# %|████████████████████████████████████████████████████████████████████▏      | 45474/50000 [07:15<00:44, 102.73it/s]
# %|█████████████████████████████████████████████████████████████████████▊     | 46542/50000 [07:25<00:33, 103.23it/s]
# %|███████████████████████████████████████████████████████████████████████▍   | 47586/50000 [07:35<00:23, 103.03it/s]
# %|████████████████████████████████████████████████████████████████████████▉  | 48623/50000 [07:45<00:13, 103.23it/s]
# %|████████████████████████████████████████████████████████████████████████▉  | 48623/50000 [07:56<00:13, 103.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [08:01<00:00, 103.80it/s]
#  22%|█████████████████▍                                                              | 5/23 [40:34<2:25:45, 485.86s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▍                                                                            | 940/50000 [00:10<08:42, 93.94it/s]
# %|██▉                                                                          | 1917/50000 [00:20<08:20, 96.14it/s]
# %|████▍                                                                        | 2914/50000 [00:30<08:01, 97.75it/s]
# %|██████                                                                       | 3911/50000 [00:40<07:51, 97.71it/s]
# %|███████▌                                                                     | 4900/50000 [00:50<07:39, 98.11it/s]
# %|█████████                                                                    | 5889/50000 [01:00<07:31, 97.76it/s]
# %|██████████▌                                                                  | 6860/50000 [01:10<07:22, 97.39it/s]
# %|████████████                                                                 | 7828/50000 [01:20<07:13, 97.17it/s]
# %|█████████████▌                                                               | 8796/50000 [01:30<07:04, 97.02it/s]
# %|███████████████                                                              | 9763/50000 [01:40<06:58, 96.16it/s]
# %|████████████████▎                                                           | 10711/50000 [01:50<06:50, 95.73it/s]
# %|█████████████████▋                                                          | 11659/50000 [02:01<06:51, 93.28it/s]
# %|███████████████████▏                                                        | 12641/50000 [02:11<06:34, 94.72it/s]
# %|████████████████████▊                                                       | 13653/50000 [02:21<06:16, 96.64it/s]
# %|██████████████████████▎                                                     | 14665/50000 [02:32<06:06, 96.50it/s]
# %|███████████████████████▊                                                    | 15673/50000 [02:42<05:51, 97.77it/s]
# %|█████████████████████████▎                                                  | 16683/50000 [02:52<05:37, 98.72it/s]
# %|██████████████████████████▉                                                 | 17693/50000 [03:02<05:26, 98.92it/s]
# %|████████████████████████████▍                                               | 18688/50000 [03:12<05:19, 97.93it/s]
# %|█████████████████████████████▉                                              | 19673/50000 [03:22<05:09, 98.10it/s]
# %|███████████████████████████████▍                                            | 20658/50000 [03:32<04:59, 97.85it/s]
# %|████████████████████████████████▉                                           | 21631/50000 [03:43<04:52, 96.95it/s]
# %|██████████████████████████████████▎                                         | 22607/50000 [03:53<04:41, 97.14it/s]
# %|███████████████████████████████████▊                                        | 23583/50000 [04:03<04:34, 96.30it/s]
# %|█████████████████████████████████████▎                                      | 24530/50000 [04:13<04:25, 95.80it/s]
# %|██████████████████████████████████████▊                                     | 25528/50000 [04:23<04:12, 96.98it/s]
# %|████████████████████████████████████████▎                                   | 26526/50000 [04:33<04:01, 97.04it/s]
# %|█████████████████████████████████████████▊                                  | 27532/50000 [04:43<03:49, 98.09it/s]
# %|███████████████████████████████████████████▍                                | 28548/50000 [04:53<03:36, 99.12it/s]
# %|████████████████████████████████████████████▉                               | 29564/50000 [05:04<03:28, 98.09it/s]
# %|██████████████████████████████████████████████▍                             | 30526/50000 [05:14<03:19, 97.51it/s]
# %|███████████████████████████████████████████████▉                            | 31504/50000 [05:24<03:09, 97.59it/s]
# %|█████████████████████████████████████████████████▍                          | 32519/50000 [05:34<02:57, 98.74it/s]
# %|██████████████████████████████████████████████████▉                         | 33534/50000 [05:45<02:49, 97.11it/s]
# %|████████████████████████████████████████████████████▍                       | 34528/50000 [05:55<02:38, 97.76it/s]
# %|██████████████████████████████████████████████████████                      | 35562/50000 [06:05<02:25, 99.42it/s]
# %|███████████████████████████████████████████████████████▋                    | 36596/50000 [06:16<02:16, 97.89it/s]
# %|█████████████████████████████████████████████████████████▏                  | 37595/50000 [06:26<02:05, 98.47it/s]
# %|██████████████████████████████████████████████████████████▋                 | 38626/50000 [06:36<01:53, 99.82it/s]
# %|███████████████████████████████████████████████████████████▍               | 39657/50000 [06:46<01:43, 100.32it/s]
# %|█████████████████████████████████████████████████████████████              | 40679/50000 [06:56<01:32, 100.86it/s]
# %|██████████████████████████████████████████████████████████████▌            | 41701/50000 [07:06<01:22, 101.07it/s]
# %|████████████████████████████████████████████████████████████████           | 42717/50000 [07:16<01:12, 100.49it/s]
# %|██████████████████████████████████████████████████████████████████▍         | 43709/50000 [07:26<01:03, 99.40it/s]
# %|███████████████████████████████████████████████████████████████████▉        | 44702/50000 [07:36<00:53, 99.34it/s]
# %|███████████████████████████████████████████████████████████████████▉        | 44702/50000 [07:48<00:53, 99.34it/s]
# %|█████████████████████████████████████████████████████████████████████▍      | 45659/50000 [07:48<00:46, 94.32it/s]
# %|█████████████████████████████████████████████████████████████████████▍      | 45659/50000 [07:58<00:46, 94.32it/s]
# %|██████████████████████████████████████████████████████████████████████▉     | 46674/50000 [07:58<00:34, 96.35it/s]
# %|██████████████████████████████████████████████████████████████████████▉     | 46674/50000 [08:08<00:34, 96.35it/s]
# %|████████████████████████████████████████████████████████████████████████▌   | 47739/50000 [08:08<00:22, 99.29it/s]
# %|████████████████████████████████████████████████████████████████████████▌   | 47739/50000 [08:18<00:22, 99.29it/s]
# %|█████████████████████████████████████████████████████████████████████████▏ | 48779/50000 [08:18<00:12, 100.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 50000/50000 [08:29<00:00, 98.12it/s]
#  26%|████████████████████▊                                                           | 6/23 [49:11<2:20:39, 496.43s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▌                                                                          | 1054/50000 [00:10<07:44, 105.40it/s]
# %|███▏                                                                        | 2108/50000 [00:20<07:34, 105.36it/s]
# %|████▊                                                                       | 3177/50000 [00:30<07:21, 106.05it/s]
# %|██████▍                                                                     | 4246/50000 [00:40<07:11, 106.06it/s]
# %|████████                                                                    | 5312/50000 [00:50<07:00, 106.23it/s]
# %|█████████▋                                                                  | 6382/50000 [01:00<06:49, 106.46it/s]
# %|███████████▎                                                                | 7452/50000 [01:10<06:40, 106.25it/s]
# %|████████████▉                                                               | 8530/50000 [01:20<06:28, 106.72it/s]
# %|██████████████▌                                                             | 9608/50000 [01:30<06:17, 106.94it/s]
# %|████████████████                                                           | 10683/50000 [01:40<06:07, 107.07it/s]
# %|█████████████████▋                                                         | 11757/50000 [01:50<05:58, 106.73it/s]
# %|███████████████████▏                                                       | 12817/50000 [02:00<05:52, 105.45it/s]
# %|████████████████████▊                                                      | 13846/50000 [02:10<05:45, 104.68it/s]
# %|██████████████████████▎                                                    | 14875/50000 [02:20<05:38, 103.87it/s]
# %|███████████████████████▊                                                   | 15901/50000 [02:30<05:29, 103.48it/s]
# %|███████████████████████▊                                                   | 15901/50000 [02:41<05:29, 103.48it/s]
# %|█████████████████████████▍                                                 | 16923/50000 [02:41<05:28, 100.83it/s]
# %|██████████████████████████▉                                                | 17924/50000 [02:51<05:18, 100.61it/s]
# %|████████████████████████████▌                                              | 19011/50000 [03:01<05:00, 103.00it/s]
# %|████████████████████████████▌                                              | 19011/50000 [03:11<05:00, 103.00it/s]
# %|██████████████████████████████▏                                            | 20089/50000 [03:11<04:46, 104.34it/s]
# %|██████████████████████████████▏                                            | 20089/50000 [03:21<04:46, 104.34it/s]
# %|███████████████████████████████▋                                           | 21139/50000 [03:21<04:36, 104.51it/s]
# %|█████████████████████████████████▎                                         | 22189/50000 [03:31<04:25, 104.63it/s]
# %|█████████████████████████████████▎                                         | 22189/50000 [03:41<04:25, 104.63it/s]
# %|██████████████████████████████████▊                                        | 23208/50000 [03:41<04:18, 103.74it/s]
# %|████████████████████████████████████▍                                      | 24256/50000 [03:51<04:07, 104.05it/s]
# %|█████████████████████████████████████▉                                     | 25332/50000 [04:01<03:54, 105.09it/s]
# %|█████████████████████████████████████▉                                     | 25332/50000 [04:11<03:54, 105.09it/s]
# %|███████████████████████████████████████▌                                   | 26406/50000 [04:11<03:43, 105.69it/s]
# %|█████████████████████████████████████████▏                                 | 27478/50000 [04:21<03:32, 106.14it/s]
# %|█████████████████████████████████████████▏                                 | 27478/50000 [04:31<03:32, 106.14it/s]
# %|██████████████████████████████████████████▊                                | 28535/50000 [04:31<03:23, 105.41it/s]
# %|████████████████████████████████████████████▍                              | 29639/50000 [04:41<03:10, 106.90it/s]
# %|████████████████████████████████████████████▍                              | 29639/50000 [04:51<03:10, 106.90it/s]
# %|██████████████████████████████████████████████                             | 30743/50000 [04:51<02:58, 107.91it/s]
# %|███████████████████████████████████████████████▊                           | 31851/50000 [05:01<02:46, 108.77it/s]
# %|█████████████████████████████████████████████████▍                         | 32970/50000 [05:11<02:35, 109.70it/s]
# %|█████████████████████████████████████████████████▍                         | 32970/50000 [05:21<02:35, 109.70it/s]
# %|███████████████████████████████████████████████████                        | 34056/50000 [05:21<02:25, 109.27it/s]
# %|████████████████████████████████████████████████████▋                      | 35140/50000 [05:31<02:16, 109.00it/s]
# %|████████████████████████████████████████████████████▋                      | 35140/50000 [05:41<02:16, 109.00it/s]
# %|██████████████████████████████████████████████████████▏                    | 36144/50000 [05:41<02:10, 106.33it/s]
# %|███████████████████████████████████████████████████████▊                   | 37227/50000 [05:51<01:59, 106.91it/s]
# %|█████████████████████████████████████████████████████████▍                 | 38313/50000 [06:01<01:48, 107.41it/s]
# %|█████████████████████████████████████████████████████████▍                 | 38313/50000 [06:11<01:48, 107.41it/s]
# %|███████████████████████████████████████████████████████████                | 39393/50000 [06:11<01:38, 107.50it/s]
# %|████████████████████████████████████████████████████████████▋              | 40480/50000 [06:21<01:28, 107.86it/s]
# %|██████████████████████████████████████████████████████████████▎            | 41557/50000 [06:31<01:18, 107.80it/s]
# %|██████████████████████████████████████████████████████████████▎            | 41557/50000 [06:31<01:18, 107.80it/s]
# %|██████████████████████████████████████████████████████████████▎            | 41557/50000 [06:41<01:18, 107.80it/s]
# %|███████████████████████████████████████████████████████████████▉           | 42620/50000 [06:42<01:08, 107.32it/s]
# %|███████████████████████████████████████████████████████████████▉           | 42620/50000 [06:52<01:08, 107.32it/s]
# %|█████████████████████████████████████████████████████████████████▌         | 43690/50000 [06:52<00:58, 107.20it/s]
# %|█████████████████████████████████████████████████████████████████▌         | 43690/50000 [07:02<00:58, 107.20it/s]
# %|███████████████████████████████████████████████████████████████████        | 44735/50000 [07:02<00:49, 105.86it/s]
# %|████████████████████████████████████████████████████████████████████▊      | 45837/50000 [07:12<00:38, 107.14it/s]
# %|██████████████████████████████████████████████████████████████████████▍    | 46939/50000 [07:22<00:28, 106.80it/s]
# %|████████████████████████████████████████████████████████████████████████   | 48049/50000 [07:32<00:18, 108.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [07:50<00:00, 106.30it/s]
#  30%|████████████████████████▎                                                       | 7/23 [57:09<2:10:44, 490.30s/it]
# %|                                                                                        | 0/50000 [00:00<?, ?it/s]
# %|█▋                                                                          | 1095/50000 [00:10<07:26, 109.44it/s]
# %|███▎                                                                        | 2190/50000 [00:20<07:18, 109.11it/s]
# %|█████                                                                       | 3301/50000 [00:30<07:04, 109.98it/s]
# %|██████▋                                                                     | 4412/50000 [00:40<06:56, 109.36it/s]
# %|████████▎                                                                   | 5501/50000 [00:50<06:47, 109.18it/s]
# %|██████████                                                                  | 6607/50000 [01:00<06:35, 109.66it/s]
# %|███████████▋                                                                | 7713/50000 [01:10<06:25, 109.82it/s]
# %|█████████████▍                                                              | 8815/50000 [01:20<06:15, 109.78it/s]
# %|███████████████                                                             | 9912/50000 [01:30<06:05, 109.74it/s]
# %|████████████████▌                                                          | 11009/50000 [01:40<05:55, 109.53it/s]
# %|██████████████████▏                                                        | 12100/50000 [01:50<05:49, 108.55it/s]
# %|███████████████████▊                                                       | 13202/50000 [02:00<05:37, 109.03it/s]
# %|█████████████████████▍                                                     | 14304/50000 [02:11<05:30, 107.95it/s]
# %|███████████████████████▏                                                   | 15431/50000 [02:21<05:16, 109.34it/s]
# %|████████████████████████▊                                                  | 16558/50000 [02:31<05:08, 108.50it/s]
# %|██████████████████████████▍                                                | 17625/50000 [02:42<05:03, 106.78it/s]
# %|███████████████████████████▉                                               | 18665/50000 [02:52<04:55, 105.96it/s]
# %|█████████████████████████████▌                                             | 19713/50000 [03:02<04:46, 105.60it/s]
# %|███████████████████████████████▏                                           | 20776/50000 [03:12<04:36, 105.78it/s]
# %|████████████████████████████████▊                                          | 21838/50000 [03:22<04:27, 105.34it/s]
# %|██████████████████████████████████▍                                        | 22932/50000 [03:32<04:14, 106.53it/s]
# ...
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  46%|███████████████████████████████████▍                                         | 4606/10000 [06:31<08:02, 11.19it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  47%|████████████████████████████████████▎                                        | 4717/10000 [06:41<07:53, 11.15it/s]
#  48%|█████████████████████████████████████▏                                       | 4828/10000 [06:51<07:51, 10.98it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  49%|█████████████████████████████████████▉                                       | 4935/10000 [07:01<07:45, 10.87it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  50%|██████████████████████████████████████▊                                      | 5042/10000 [07:12<07:44, 10.68it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  52%|███████████████████████████████████████▋                                     | 5155/10000 [07:22<07:27, 10.84it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  53%|████████████████████████████████████████▌                                    | 5268/10000 [07:32<07:17, 10.82it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  54%|█████████████████████████████████████████▍                                   | 5376/10000 [07:43<07:09, 10.75it/s]
#  55%|██████████████████████████████████████████▏                                  | 5482/10000 [07:53<07:02, 10.69it/s]
#  56%|███████████████████████████████████████████                                  | 5588/10000 [08:05<07:25,  9.90it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  57%|███████████████████████████████████████████▊                                 | 5697/10000 [08:15<07:02, 10.18it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  58%|████████████████████████████████████████████▋                                | 5806/10000 [08:26<06:46, 10.32it/s]
#  59%|█████████████████████████████████████████████▌                               | 5913/10000 [08:36<06:39, 10.23it/s]
#  60%|██████████████████████████████████████████████▎                              | 6019/10000 [08:46<06:25, 10.33it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  61%|███████████████████████████████████████████████▏                             | 6132/10000 [08:56<06:04, 10.60it/s]
#  62%|████████████████████████████████████████████████                             | 6249/10000 [09:06<05:43, 10.91it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  64%|█████████████████████████████████████████████████                            | 6366/10000 [09:17<05:36, 10.80it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  65%|█████████████████████████████████████████████████▉                           | 6480/10000 [09:27<05:21, 10.96it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  66%|██████████████████████████████████████████████████▊                          | 6594/10000 [09:38<05:09, 11.01it/s]
#  67%|███████████████████████████████████████████████████▋                         | 6706/10000 [09:48<04:59, 10.99it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  68%|████████████████████████████████████████████████████▍                        | 6816/10000 [09:58<04:50, 10.97it/s]
#  69%|█████████████████████████████████████████████████████▎                       | 6926/10000 [10:10<04:52, 10.49it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  70%|██████████████████████████████████████████████████████▏                      | 7044/10000 [10:20<04:32, 10.86it/s]
#  72%|███████████████████████████████████████████████████████▏                     | 7163/10000 [10:30<04:14, 11.16it/s]
#  73%|████████████████████████████████████████████████████████                     | 7282/10000 [10:40<04:01, 11.25it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  74%|████████████████████████████████████████████████████████▉                    | 7397/10000 [10:50<03:51, 11.26it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  75%|█████████████████████████████████████████████████████████▊                   | 7510/10000 [11:00<03:41, 11.23it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  76%|██████████████████████████████████████████████████████████▋                  | 7625/10000 [11:10<03:30, 11.30it/s]
#  76%|██████████████████████████████████████████████████████████▋                  | 7625/10000 [11:21<03:30, 11.30it/s]
#  77%|███████████████████████████████████████████████████████████▌                 | 7737/10000 [11:21<03:24, 11.07it/s]
#  78%|████████████████████████████████████████████████████████████▍                | 7843/10000 [11:31<03:17, 10.93it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  80%|█████████████████████████████████████████████████████████████▏               | 7953/10000 [11:41<03:07, 10.92it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  81%|██████████████████████████████████████████████████████████████               | 8062/10000 [11:52<03:04, 10.50it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  82%|██████████████████████████████████████████████████████████████▉              | 8166/10000 [12:02<02:55, 10.46it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  83%|███████████████████████████████████████████████████████████████▋             | 8277/10000 [12:12<02:41, 10.64it/s]
#  84%|████████████████████████████████████████████████████████████████▌            | 8388/10000 [12:24<02:37, 10.26it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  85%|█████████████████████████████████████████████████████████████████▍           | 8493/10000 [12:34<02:25, 10.33it/s]
#  86%|██████████████████████████████████████████████████████████████████▏          | 8598/10000 [12:47<02:25,  9.65it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  87%|███████████████████████████████████████████████████████████████████          | 8703/10000 [12:57<02:11,  9.88it/s]
#  88%|███████████████████████████████████████████████████████████████████▊         | 8814/10000 [13:07<01:55, 10.23it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  89%|████████████████████████████████████████████████████████████████████▋        | 8925/10000 [13:17<01:43, 10.43it/s]
#  90%|█████████████████████████████████████████████████████████████████████▌       | 9035/10000 [13:28<01:34, 10.25it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  91%|██████████████████████████████████████████████████████████████████████▎      | 9134/10000 [13:39<01:26, 10.04it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  92%|███████████████████████████████████████████████████████████████████████      | 9230/10000 [13:49<01:18,  9.87it/s]
#  93%|███████████████████████████████████████████████████████████████████████▊     | 9331/10000 [13:59<01:07,  9.92it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  94%|████████████████████████████████████████████████████████████████████████▋    | 9432/10000 [14:09<00:57,  9.87it/s]
#  95%|█████████████████████████████████████████████████████████████████████████▍   | 9531/10000 [14:19<00:47,  9.86it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  96%|██████████████████████████████████████████████████████████████████████████▏  | 9630/10000 [14:31<00:39,  9.40it/s]
#  96%|██████████████████████████████████████████████████████████████████████████▏  | 9630/10000 [14:41<00:39,  9.40it/s]
#  97%|██████████████████████████████████████████████████████████████████████████▋  | 9701/10000 [14:41<00:34,  8.65it/s]
#  98%|███████████████████████████████████████████████████████████████████████████▏ | 9770/10000 [14:52<00:29,  7.88it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  99%|███████████████████████████████████████████████████████████████████████████▊ | 9853/10000 [15:02<00:18,  7.99it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  99%|████████████████████████████████████████████████████████████████████████████▌| 9936/10000 [15:13<00:08,  7.98it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [15:20<00:00, 10.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [15:20<00:00, 920.80s/it]

# %%
temp_ss_data.describe()
# Out:
#        samp_biased   ddc_biased    jn_biased  realized_size_biased  \
# count  5000.000000  5000.000000  5000.000000           5000.000000
# mean      1.521020     0.017120     0.120167           1123.358200
# std       0.094327     0.002544     0.005481             15.008029
# min       1.162610     0.006178     0.100422           1066.000000
# 25%       1.455346     0.015405     0.116503           1113.000000
# 50%       1.518398     0.017148     0.120080           1123.000000
# 75%       1.583271     0.018850     0.123748           1134.000000
# max       1.870004     0.026127     0.144001           1187.000000
#
#        samp_intended  ddc_intended  jn_intended  sample_size      pop_beta  \
# count    5000.000000   5000.000000  5000.000000       5000.0  5.000000e+03
# mean        1.011313     -0.000072     0.143971       1400.0  1.010783e+00
# std         0.070459      0.003183     0.005580          0.0  2.220668e-16
# min         0.787433     -0.011733     0.122373       1400.0  1.010783e+00
# 25%         0.963509     -0.002198     0.140098       1400.0  1.010783e+00
# 50%         1.010032     -0.000034     0.143960       1400.0  1.010783e+00
# 75%         1.059186      0.002150     0.147777       1400.0  1.010783e+00
# max         1.286085      0.011456     0.167087       1400.0  1.010783e+00
#
#         mse_biased  mse_intended
# count  5000.000000  5.000000e+03
# mean      0.269238  4.963701e-03
# std       0.098586  7.057778e-03
# min       0.023051  5.799448e-11
# 25%       0.197637  5.044485e-04
# 50%       0.257673  2.296789e-03
# 75%       0.327743  6.591521e-03
# max       0.738261  7.579127e-02
