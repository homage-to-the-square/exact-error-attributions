# %% [markdown]
# can also check the linear independence of rho and Jn here as well!

# %% [markdown]
# # Imports:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression

from scipy.stats import chi2
from collections import Counter

from itertools import permutations
from tqdm import tqdm, trange

# %%
import matplotlib.pyplot as plt

import pickle

import statsmodels.api as sm

from collections import defaultdict

from scipy.linalg import sqrtm

from scipy.special import expit, logit

# %% [markdown]
# # Helper Functions:

# %%
from scipy.stats import norm

# %%
import sys

sys.path.append('../')

from ddc_utils import *
from data_generating_utils import *

# %% [markdown]
# # Hyperparams:

# %%
pop_index = 1
iter_val = 0

# %%
rand_generator = np.random.default_rng(seed=333 * pop_index + iter_val)

# %%
population_size = 100_000

number_of_coefficients = 1

num_iters_per_population = 25_000
true_beta = -1
link = 'Probit'

# %%
ALL_SAMPLE_SIZES = [1000]

# %% [markdown]
# # Run:

# %%
feature_cols = [f'x_{i}' for i in range(number_of_coefficients)]

# %%
# hypervariabes where things will be saved as key of sample size -> list.
all_jns_per_sample_size_biased = defaultdict(list)
all_ddc_per_sample_size_biased = defaultdict(list)
all_sample_beta_per_sample_size_biased = defaultdict(list)

all_jns_per_sample_size_full = defaultdict(list)
all_ddc_per_sample_size_full = defaultdict(list)
all_sample_beta_per_sample_size_full = defaultdict(list)



all_realized_sample_sizes_per_sample_size = defaultdict(list)
all_pop_beta_per_sample_size = defaultdict(list)

sample_specific_non_separable_count = {}

# %%
sample_probability_centering = 0.77
sample_probability_bias_factor = 1

# %%
pop_data = generate_population_data(population_size, number_of_coefficients, 
                                    feature_cols = feature_cols, true_beta = true_beta, link = link)

# %%
pickle_filename = f'base_population_data_{link}_{true_beta}.pickle'
with open(pickle_filename, 'wb') as handle:
    pickle.dump(pop_data, handle)

# %%
model_iteration = [(0, 'Logit'), (1, 'Probit'), (2, 'CLogLog')]

# %% [markdown]
# #### get population-level statistics:

# %%
pop_x = pop_data[feature_cols]
pop_y = pop_data['y']

pop_model = sm.Logit(endog = pop_y, exog = pop_x).fit(disp=0)
pop_beta = np.array(pop_model.params)
pop_gs = pop_x * (np.array(pop_y).reshape((population_size, 1)) - \
              np.array(pop_model.predict()).reshape((population_size, 1)))

# %% [markdown]
# compute the population models:

# %%
def compute_all_three_logistic_models(x_data, y_data):
    temp_logit_model = sm.Logit(endog = y_data, exog = x_data).fit(disp=0)
    temp_probit_model = sm.GLM(y_data, x_data, family=sm.families.Binomial(link=sm.families.links.Probit())).fit()
    temp_cloglog_model = sm.GLM(y_data, x_data, family=sm.families.Binomial(link=sm.families.links.CLogLog())).fit()
    return [temp_logit_model, temp_probit_model, temp_cloglog_model]

# %%
population_models = compute_all_three_logistic_models(pop_x, pop_y)
pop_logit_model, pop_probit_model, pop_cloglog_model = population_models

# %% [markdown]
# save their betas:

# %%
pop_betas = [np.array(pop_logit_model.params), 
             np.array(pop_probit_model.params), 
             np.array(pop_cloglog_model.params)]

# %%
pop_betas
# Out:
# [array([-1.71911032]), array([-1.01134822]), array([-0.93085243])]

# %% [markdown]
# compute the gs:

# %%
pop_gs = {}

# %%
pop_gs['Logit'] = pop_x * (np.array(pop_y).reshape((population_size, 1)) - \
                    np.array(pop_logit_model.predict()).reshape((population_size, 1)))

# %%
# compute probit gs 
temp_mu_is = pop_probit_model.predict()
variance_denominator = 1/((temp_mu_is) * (1 - temp_mu_is))
dmu_dg = norm.pdf(pop_x @ pop_probit_model.params)
pop_gs['Probit'] = pop_x.mul(((pop_y - temp_mu_is) * variance_denominator * dmu_dg), axis=0)

# %%
# compute cloglog gs 
temp_mu_is = pop_cloglog_model.predict()
variance_denominator = 1/((temp_mu_is) * (1 - temp_mu_is))
dmu_dg = np.log(1 - temp_mu_is) * (temp_mu_is - 1)
pop_gs['CLogLog'] = pop_x.mul(((pop_y - temp_mu_is) * variance_denominator * dmu_dg), axis=0)
# Out:
# C:\Users\Jason\AppData\Local\Temp\ipykernel_25816\2301846130.py:3: RuntimeWarning: divide by zero encountered in divide
#   variance_denominator = 1/((temp_mu_is) * (1 - temp_mu_is))
# C:\Users\Jason\AppData\Local\Temp\ipykernel_25816\2301846130.py:4: RuntimeWarning: divide by zero encountered in log
#   dmu_dg = np.log(1 - temp_mu_is) * (temp_mu_is - 1)
# C:\Users\Jason\AppData\Local\Temp\ipykernel_25816\2301846130.py:4: RuntimeWarning: invalid value encountered in multiply
#   dmu_dg = np.log(1 - temp_mu_is) * (temp_mu_is - 1)

# %% [markdown]
# #### actually run:

# %%
for temp_sample_size in tqdm(ALL_SAMPLE_SIZES):
    non_separable_count = 0
    num_iters_per_population = 10_000
        
    for _ in trange(num_iters_per_population, mininterval=10):
        # use sampling scheme to sample data:
        obtained_valid_sample = False
        
        while not obtained_valid_sample:
            pop_data['r0'] = 0
            pop_data.loc[np.random.choice(pop_data.index, size = temp_sample_size, replace=False), 'r0'] = 1

            pop_data['r'] = 0
            
            full_sampled_data = pop_data[pop_data['r0'] == 1]

            marginal_probabilities = expit(logit(sample_probability_centering) + \
                                           sample_probability_bias_factor * (2* full_sampled_data['y'] - 1) * \
                                           full_sampled_data['x_0'])

            other_sample_indices = marginal_probabilities.index[rand_generator.binomial(n=1, p = marginal_probabilities) == 1]

            pop_data.loc[other_sample_indices, 'r'] = 1
            # sample_data here means the biased sample data.
            sample_data = pop_data[pop_data['r'] == 1]
            realised_sample_size = len(other_sample_indices)
            
            if realised_sample_size < 1_000:
                separability_check_df = sample_data[['x_0', 'y']].groupby('y')['x_0'].agg(['min', 'max'])
                is_not_separable = (len(separability_check_df) < 2) or \
                                    (separability_check_df.iloc[0, 0] > separability_check_df.iloc[1, 1]) or \
                                    (separability_check_df.iloc[1, 0] > separability_check_df.iloc[0, 1])

                if is_not_separable:
                    non_separable_count = non_separable_count + 1
                    continue

            else:
                ...
            obtained_valid_sample = True
            
            # compute biased x, y, model, beta
            sample_x = sample_data[feature_cols]
            sample_y = sample_data['y']
            sample_models = compute_all_three_logistic_models(sample_x, sample_y)
            sample_betas = [sample_model.params for sample_model in sample_models]
            sample_r = pop_data['r']
        
        # compute full x, y, model, beta
        sample_x_full = full_sampled_data[feature_cols]
        sample_y_full = full_sampled_data['y']
        sample_models_full = compute_all_three_logistic_models(sample_x_full, sample_y_full)
        sample_betas_full = [sample_model_full.params for sample_model_full in sample_models_full]
        sample_r_full = pop_data['r0']
        
        
        
        # compute biased versions of things:
        all_sample_beta_per_sample_size_biased[temp_sample_size].append(
            [pd.Series(sample_beta) for sample_beta in sample_betas]
        )        
        all_ddc_per_sample_size_biased[temp_sample_size].append(
                        [pop_gs[model_type].corrwith(sample_r)[['x_0']] for _, model_type in model_iteration]
        )
        all_jns_per_sample_size_biased[temp_sample_size].append(
            [compute_average_jn(pop_betas[model_index], sample_betas[model_index], 
                               sample_x, sample_y, model_type = model_type) for model_index, model_type in model_iteration]
        )
            
        all_realized_sample_sizes_per_sample_size[temp_sample_size].append(realised_sample_size)
        
        # compute full versions of things:
        all_sample_beta_per_sample_size_full[temp_sample_size].append(
            [pd.Series(sample_beta) for sample_beta in sample_betas_full]
        )
        
        all_ddc_per_sample_size_full[temp_sample_size].append(
            [pop_gs[model_type].corrwith(sample_r_full)[['x_0']] for _, model_type in model_iteration]
        )
        
        all_jns_per_sample_size_full[temp_sample_size].append(
            [compute_average_jn(pop_betas[model_index], sample_betas_full[model_index], 
                               sample_x_full, sample_y_full, 
                               model_type = model_type) for model_index, model_type in model_iteration]
        )
        
    sample_specific_non_separable_count[temp_sample_size] = non_separable_count
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#   0%|                                                                                        | 0/10000 [00:00<?, ?it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   1%|▊                                                                              | 97/10000 [00:10<17:04,  9.67it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   2%|█▌                                                                            | 194/10000 [00:20<17:27,  9.36it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   3%|██▎                                                                           | 290/10000 [00:30<17:05,  9.47it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   4%|███                                                                           | 389/10000 [00:40<16:40,  9.61it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   5%|███▊                                                                          | 488/10000 [00:51<16:35,  9.55it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   6%|████▌                                                                         | 583/10000 [01:01<16:30,  9.51it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   7%|█████▎                                                                        | 678/10000 [01:11<16:31,  9.40it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   8%|██████                                                                        | 771/10000 [01:21<16:26,  9.35it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#   9%|██████▋                                                                       | 864/10000 [01:31<16:24,  9.28it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  10%|███████▍                                                                      | 957/10000 [01:41<16:15,  9.27it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  11%|████████                                                                     | 1051/10000 [01:52<16:03,  9.29it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  12%|████████▊                                                                    | 1151/10000 [02:02<15:32,  9.49it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  13%|█████████▋                                                                   | 1251/10000 [02:12<15:30,  9.41it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  13%|██████████▍                                                                  | 1349/10000 [02:22<15:11,  9.50it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  14%|███████████▏                                                                 | 1447/10000 [02:33<14:59,  9.51it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  15%|███████████▉                                                                 | 1543/10000 [02:43<14:57,  9.42it/s]
#  16%|████████████▌                                                                | 1636/10000 [02:53<14:59,  9.30it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  17%|█████████████▎                                                               | 1729/10000 [03:04<14:50,  9.29it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  18%|██████████████                                                               | 1823/10000 [03:14<14:38,  9.30it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  19%|██████████████▊                                                              | 1917/10000 [03:24<14:31,  9.27it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  20%|███████████████▍                                                             | 2012/10000 [03:34<14:16,  9.32it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  21%|████████████████▏                                                            | 2107/10000 [03:44<14:11,  9.27it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  22%|████████████████▉                                                            | 2202/10000 [03:54<13:57,  9.32it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  23%|█████████████████▋                                                           | 2301/10000 [04:04<13:32,  9.47it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  24%|██████████████████▍                                                          | 2400/10000 [04:15<13:31,  9.36it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  25%|███████████████████▎                                                         | 2500/10000 [04:25<13:06,  9.54it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  26%|████████████████████                                                         | 2600/10000 [04:35<12:45,  9.67it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  27%|████████████████████▊                                                        | 2700/10000 [04:47<13:09,  9.24it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  28%|█████████████████████▍                                                       | 2786/10000 [04:57<13:18,  9.03it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  29%|██████████████████████▏                                                      | 2884/10000 [05:07<12:50,  9.23it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  30%|██████████████████████▉                                                      | 2987/10000 [05:17<12:15,  9.53it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  31%|███████████████████████▊                                                     | 3090/10000 [05:28<11:52,  9.70it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  32%|████████████████████████▌                                                    | 3194/10000 [05:38<11:27,  9.90it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  33%|█████████████████████████▍                                                   | 3300/10000 [05:48<11:05, 10.07it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  34%|██████████████████████████▏                                                  | 3405/10000 [05:58<10:54, 10.07it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  35%|██████████████████████████▉                                                  | 3506/10000 [06:09<10:56,  9.89it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  36%|███████████████████████████▊                                                 | 3609/10000 [06:19<10:39, 10.00it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  37%|████████████████████████████▌                                                | 3714/10000 [06:29<10:21, 10.12it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  38%|█████████████████████████████▍                                               | 3819/10000 [06:39<10:07, 10.17it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  39%|██████████████████████████████▏                                              | 3923/10000 [06:50<09:59, 10.14it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  40%|███████████████████████████████                                              | 4027/10000 [07:00<09:46, 10.18it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  40%|███████████████████████████████                                              | 4027/10000 [07:10<09:46, 10.18it/s]
#  41%|███████████████████████████████▋                                             | 4122/10000 [07:10<09:54,  9.89it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  42%|████████████████████████████████▍                                            | 4220/10000 [07:20<09:47,  9.84it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  43%|█████████████████████████████████▎                                           | 4319/10000 [07:31<09:52,  9.59it/s]
#  43%|█████████████████████████████████▎                                           | 4319/10000 [07:31<09:52,  9.59it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  43%|█████████████████████████████████▎                                           | 4319/10000 [07:41<09:52,  9.59it/s]
#  44%|██████████████████████████████████                                           | 4417/10000 [07:41<09:39,  9.63it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
# ...
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  84%|████████████████████████████████████████████████████████████████▋            | 8393/10000 [14:51<02:59,  8.93it/s]
#  85%|█████████████████████████████████████████████████████████████████▎           | 8487/10000 [14:51<02:47,  9.05it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  86%|██████████████████████████████████████████████████████████████████           | 8581/10000 [15:03<02:44,  8.65it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  87%|██████████████████████████████████████████████████████████████████▊          | 8682/10000 [15:13<02:25,  9.05it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  88%|███████████████████████████████████████████████████████████████████▋         | 8783/10000 [15:24<02:11,  9.28it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  89%|████████████████████████████████████████████████████████████████████▍        | 8882/10000 [15:34<02:00,  9.27it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  90%|█████████████████████████████████████████████████████████████████████        | 8976/10000 [15:44<01:50,  9.29it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  91%|█████████████████████████████████████████████████████████████████████▉       | 9078/10000 [15:55<01:36,  9.54it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  92%|██████████████████████████████████████████████████████████████████████▋      | 9180/10000 [16:06<01:26,  9.45it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  93%|███████████████████████████████████████████████████████████████████████▍     | 9277/10000 [16:16<01:15,  9.51it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  94%|████████████████████████████████████████████████████████████████████████▏    | 9374/10000 [16:26<01:06,  9.45it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  95%|█████████████████████████████████████████████████████████████████████████    | 9481/10000 [16:36<00:52,  9.80it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  96%|█████████████████████████████████████████████████████████████████████████▊   | 9588/10000 [16:47<00:41,  9.88it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  97%|██████████████████████████████████████████████████████████████████████████▋  | 9692/10000 [16:57<00:30, 10.01it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  98%|███████████████████████████████████████████████████████████████████████████▌ | 9806/10000 [17:07<00:18, 10.41it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#
#  99%|████████████████████████████████████████████████████████████████████████████▍| 9924/10000 [17:17<00:07, 10.82it/s]C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Jason\.conda\envs\airsoft\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [17:23<00:00,  9.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [17:23<00:00, 1043.80s/it]

# %% [markdown]
# #### combine data for each sample size:

# %%
sample_specific_non_separable_count
# Out:
# {1000: 0}

# %%
all_data_per_ss = []

# %%
all_raw_data = [all_jns_per_sample_size_biased, all_ddc_per_sample_size_biased, all_sample_beta_per_sample_size_biased, \
                all_jns_per_sample_size_full, all_ddc_per_sample_size_full, all_sample_beta_per_sample_size_full, \
                all_realized_sample_sizes_per_sample_size, all_pop_beta_per_sample_size]

# %%
pickle_filename = f'all_raw_data_{link}_{true_beta}.pickle'
with open(pickle_filename, 'wb') as handle:
    pickle.dump(all_raw_data, handle)

# %%
pickle_filename = f'pop_betas_{link}_{true_beta}.pickle'
with open(pickle_filename, 'wb') as handle:
    pickle.dump(pop_betas, handle)
